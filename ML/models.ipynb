# %%
# Update sklearn to prevent version mismatches
#!pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
#!pip install joblib

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 4000

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("diagnosis-of-covid-19-and-its-clinical-spectrum.csv")
# Drop the null columns where all values are null
# df = df.dropna(axis='columns', how='all')
# Drop the null rows
# df = df.dropna()
df.head()
df_positive = df.loc[df["sars_cov_2_exam_result"]=="positive"]
df_positive
# Out:
#            patient_id  patient_age_quantile sars_cov_2_exam_result  \
# 67    78511c183ae18bc                     7               positive
# 284   d7834ed75f2da44                    16               positive
# 513   b16b49f7bd3e692                    10               positive
# 568   4382f5ea05e60c4                     2               positive
# 676   d3729cd2658ca64                    15               positive
# 884   ab9745da9d139b9                    15               positive
# 1011  a0435dd40e745fd                     7               positive
# 1108  9d7c293a6773d6a                    14               positive
# 1113  ff5ec3abd7d6088                     5               positive
# 1129  7b1d6bf5993aa9b                     9               positive
# 1156  1e7e33688edc5a9                    11               positive
# 1162  2a5db9bbb45109f                    14               positive
# 1168  3fc734fd9bafbd6                    18               positive
# 1193  057e8ce3c6f2f31                    14               positive
# 1194  f0ee30f04652697                    11               positive
# 1196  8fac8033edbd319                    13               positive
# 1201  219ad2543c93936                    14               positive
# 1205  ff34f2c79fc6cf0                     7               positive
# 1232  fbec53bbe8c576a                     6               positive
# 1268  66d288d2a12ca60                    14               positive
# 1293  2081f4ac7e7ee9b                     7               positive
# 1309  8093f6c0168c627                     8               positive
# 1313  be0703dfbedad9a                     4               positive
# 1324  7a02fb96aa0400e                     5               positive
# 1328  bbc031943952afa                    10               positive
# 1339  6385daf6d274a67                     4               positive
# 1348  6e2b933a9d9af84                     6               positive
# 1369  e00ef039cdb2b3e                     7               positive
# 1387  a78a062f71face5                     4               positive
# 1393  44c16f1e79380b4                     8               positive
# 1394  1e0eaf4fd85f597                     6               positive
# 1400  14acdd505a4d3e4                     5               positive
# 1404  bd3019ab6fae2f1                     6               positive
# 1416  b5cb626b12df246                    18               positive
# 1423  f5c1fa2864a0020                     6               positive
# 1428  5c2a444374ac409                     6               positive
# 1431  7b0e4462ae88a50                     5               positive
# 1432  d4a33447d966127                    11               positive
# 1442  7be14fb4f79c9d8                     4               positive
# 1451  cd44e3032b8a5be                     6               positive
# 1460  205c84d73a75267                     0               positive
# 1461  cf43372f03dec9d                     5               positive
# 1476  4c79d9ace2a9744                     4               positive
# 1479  5ae6bde2a650eca                     3               positive
# 1487  ee2f3aa68b4e21c                     4               positive
# 1489  951226477dede62                     9               positive
# 1494  d168af23957bd46                     5               positive
# 1516  bb97708f7354c14                     5               positive
# 1517  bbc3e95acbb64d6                     4               positive
# 1530  a665e33ec22b37d                     5               positive
# 1533  2e254f0b59bbec9                     5               positive
# 1536  337e143c740621d                    11               positive
# 1539  41855b71fb35ba5                     9               positive
# 1548  9a9ed97e0d6eca3                     4               positive
# 1566  27f62aed65c7138                     9               positive
# 1574  1ba16f8aaa810c5                    12               positive
# 1576  999768e45ea3e92                    15               positive
# 1577  5ea443e2ac871d0                     8               positive
# 1586  938004044cac19f                     6               positive
# 1615  0b2de54a459532b                     5               positive
# 1624  0db48a8b167bcf7                    10               positive
# 1628  f8155794dc75f59                     5               positive
# 1644  1ec87f54d66ed18                    19               positive
# 1647  64fd1563a3439a4                    10               positive
# 1651  78982c04920a74d                     5               positive
# 1680  34b1de97de37241                     4               positive
# 1698  55ad1f2d262ac55                     5               positive
# 1701  01e9ec097c85377                    14               positive
# 1705  aa4232273cdb909                     2               positive
# 1713  dd207d1842d45ba                    19               positive
# 1723  1b6a203a2438f24                     2               positive
# 1726  1f552cb3d58fe6c                     9               positive
# 1749  1c7ce2c396bc771                    14               positive
# 1750  10a4537bf58a3b5                     6               positive
# 1786  8de837f236b571f                     4               positive
# 1792  6683898dc674df8                    14               positive
# 1796  ccce1027e2bac9a                    14               positive
# 1801  91929f0fd94e5b4                     7               positive
# 1844  ee5244ccb140bcf                    15               positive
# 1849  5586bf0d80afb70                    16               positive
# 1858  4c5d16f2242d413                    11               positive
# 1879  b9a698635fced54                     5               positive
# 1885  ce2cff13d735c48                    15               positive
# 1886  0161b6af50624fd                     2               positive
# 1898  07edb2faf4d7d4b                     3               positive
# 1905  695a409e4e37720                    15               positive
# 1962  0692fcdf9863763                     5               positive
# 1966  66342a96fc1f90b                    14               positive
# 1973  47a1e04238b468a                     4               positive
# 2034  0115f992c29d8af                    10               positive
# 2038  05342a9f08cf4ec                     5               positive
# 2055  906d2ee55d67bdb                     8               positive
# 2074  c846a3dc51b8606                    18               positive
# 2114  48baf76fa6f398a                    12               positive
# 2119  11fc64d4bc22d4c                     5               positive
# 2140  6a0aed0bbe495a9                    10               positive
# 2141  f85bd865caa2f0f                     3               positive
# 2161  1e33b02b0828bc9                    12               positive
# 2167  71b023d8660a0ae                     9               positive
# 2205  82718b243c40cd4                     5               positive
# 2206  f957b0bb10f2a88                    15               positive
# 2215  c38d17f887969ed                     4               positive
# 2237  2a769e947b0c3d9                    13               positive
# 2241  b57acd9d9f1e4db                    14               positive
# 2249  01596f72ec049fa                    11               positive
# 2251  7bf1cb39f81e261                    16               positive
# 2252  191fdb53482a085                    16               positive
# 2262  03b1a146884942a                     3               positive
# 2299  797d8250330ebdb                     9               positive
# 2326  7a66137c45faf0a                    11               positive
# 2336  defe1dbd487fd92                     4               positive
# 2381  aedefc93942f435                    12               positive
# 2392  5360bfe1f3082d3                    14               positive
# 2423  261a1ccaefae5e1                    16               positive
# 2426  24bbd7419b799cb                    13               positive
# 2442  999273458e6c3c1                    11               positive
# 2466  045114ed8138e00                    19               positive
# 2477  794346399cac402                    14               positive
# 2484  265aa8eb352be25                    16               positive
# 2487  33a0cbc84a23fee                    13               positive
# 2527  96b267be84d2332                     7               positive
# 2565  5fc69d164cf1442                     9               positive
# 2569  af4292a01143752                    14               positive
# 2600  16f62d45fbaa014                    11               positive
# 2679  1daaa1496f7f5cb                    12               positive
# 2683  9e9770ccbc1ed34                    13               positive
# 2722  2469e12328625ef                    11               positive
# 2758  e66cf6d2dc63f8c                     5               positive
# 2816  c569b5c375b7efa                     4               positive
# 2828  5ef288c505dab3b                     4               positive
# 2834  21be2fec728542e                     9               positive
# 2844  5d03dc24a44176d                     7               positive
# 2865  2b30a8dbc1b4ae7                    10               positive
# 2934  f346dff9f5c8763                    15               positive
# 2950  8c8b90d6981e1ba                     8               positive
# 2951  728243c7cb3d41e                     3               positive
# 2959  6f3583f50c52009                     5               positive
# 2986  4d77bd5237b6440                    14               positive
# 2993  b4a47130cce7397                     4               positive
# 3016  216344bac525faf                    12               positive
# 3026  e353e454dc6d855                     5               positive
# 3057  17451e035496552                    17               positive
# 3060  a2f3affefabc82d                    10               positive
# 3085  b3b0594e8259848                    16               positive
# 3108  fc095e809c7264a                    14               positive
# 3160  259276fe0d66e0a                    12               positive
# 3161  63c6217b3f908e4                    17               positive
# 3167  7a09111ac2bed6f                    13               positive
# 3184  d9367a002b18fd6                    13               positive
# 3193  bce6edcf216f8eb                     5               positive
# 3210  bcc55634a68a0b4                     5               positive
# 3214  5b1cc273ed4ae74                     6               positive
# 3254  5d69e46bb88d5b2                     7               positive
# 3261  6abc019f97f4798                    13               positive
# 3281  2478d330a8d6c8c                     4               positive
# 3283  db9003c11fb7823                    14               positive
# 3295  c6f861c558efd46                     4               positive
# 3302  9f13872249af783                     5               positive
# 3325  5b06d0e80f71133                    19               positive
# 3379  50f380c7ee938e9                     2               positive
# 3384  8de65927703c470                    19               positive
# 3393  280c15198774b3c                     8               positive
# 3394  99d3e75dd91e2fb                     6               positive
# 3412  83e63a5bf725b0d                     5               positive
# 3458  807de3f3d4abbe0                    10               positive
# 3459  9128f5fa87b3118                    16               positive
# 3462  1768edc36b56d97                     8               positive
# 3465  c037451a5e214e4                     9               positive
# 3471  328f86fad6a7f5d                     7               positive
# 3491  bc01e5089e9988f                     7               positive
# 3514  ad74da9105975c0                    12               positive
# 3515  bbccd97e41eec6f                     3               positive
# 3527  e5d6e8771a2fabf                    11               positive
# 3531  eca5fa1aa27df41                    14               positive
# 3548  789253f812cad7f                     8               positive
# 3569  bec3e5e879a1906                     5               positive
# 3571  230e7e4419e3ed6                     5               positive
# 3583  b9fe7b863fd6be1                    15               positive
# 3588  02a743f3bb71d35                    18               positive
# 3589  f64af783491dd82                    16               positive
# 3625  079081a49999baf                     5               positive
# 3627  efba08886eed4d9                    16               positive
# 3640  49d38c78d959b95                    17               positive
# 3665  334a08fb6e1e9cb                    16               positive
# 3667  fd02869c1ab15f8                    14               positive
# 3694  6dc6abc35fe583a                    13               positive
# 3701  f43e97741e4abae                     8               positive
# 3779  66ebb3605c26c38                    12               positive
# 3781  6507382740e0678                    13               positive
# 3789  0461443399b27d5                    11               positive
# 3793  90493e84d12a0c3                     9               positive
# 3809  52c84ca2af38270                    19               positive
# 3818  e453b3d4bd51d0d                    19               positive
# 3822  2f6928647a6f495                     9               positive
# 3823  030199c743cfe36                     3               positive
# 3831  c984e71e4316b65                     4               positive
# 3845  a4b7a26dcc845b7                    17               positive
# 3855  0a3ecf9fc8ada18                    19               positive
# 3866  0bacace4c92422c                    14               positive
# 3877  d38998dc36bd78b                    19               positive
# 3879  ee224510b31f15c                    11               positive
# 3881  23436671c65cdf6                    18               positive
# 3885  7430cb807e5f134                    15               positive
# 3890  ab426e8e3333d35                    14               positive
# 3901  8c37838f122f31b                     3               positive
# 3955  545f15b81881d51                     9               positive
# 3957  e9d9c9881d8fa88                     4               positive
# 3958  77f4335cb56d020                    18               positive
# 3960  8363ee80a84c7ec                     7               positive
# 3972  266526e939f50b0                    11               positive
# 3974  d04eb0feb999174                     9               positive
# 3987  010d0ffe8b83059                    12               positive
# 4006  50642cda0f3c864                     7               positive
# 4008  0ca47edd1691144                     6               positive
# 4009  99ffb26f2c8760b                     8               positive
# 4020  e2a086c8980b7d4                    13               positive
# 4046  a217b6a9c396e31                     9               positive
# 4058  0c744649bbfd445                     4               positive
# 4087  73edb062debce45                    16               positive
# 4090  a412f06cd27f6db                    15               positive
# 4097  56c2d960e8c9c85                    18               positive
# 4104  8a145e6923f219e                     4               positive
# 4118  fe87c566a06036e                     6               positive
# 4120  fd44054b4168e33                     7               positive
# 4126  e67b63009b22a92                    19               positive
# 4130  045c449be394fa1                    14               positive
# 4138  a23591e41d39e86                     5               positive
# 4153  d9a30d3b1517675                    11               positive
# 4156  e42bc59a1f5ffea                     4               positive
# 4161  ca37ce3285aa545                     5               positive
# 4162  116a1dcebd562e2                     4               positive
# 4182  634418e85664ccd                     7               positive
# 4188  51e471e35f626e9                     7               positive
# 4198  9834b3cb435c175                    13               positive
# 4203  3751abeecbfa53b                    17               positive
# 4209  c6bbcd6c2a5ddb2                     6               positive
# 4215  a2ec32ee385921d                     9               positive
# 4235  3f368927e2fb291                     8               positive
# 4250  e783c36642975ca                    14               positive
# 4262  4d43f1fd2d62880                     9               positive
# 4277  b5ba2556a5a2cd6                    17               positive
# 4284  0892b89417995d6                    19               positive
# 4289  eed140f67f9480f                    19               positive
# 4333  3cc34f86d95d548                     3               positive
# 4346  3a7060e4dd38e7a                    10               positive
# 4360  0ceb4cdf0f4829d                     3               positive
# 4361  fbddf32e2e255f1                    14               positive
# 4397  5bf4c4bf0c34442                     6               positive
# 4425  248a19b387e9d5d                    12               positive
# 4429  c87ce2a36b3693e                    19               positive
# 4452  6b5f0b854d07eca                    11               positive
# 4453  6ce21a3d1ffeeef                    12               positive
# 4459  1fb83a73999bcab                    19               positive
# 4460  ceb711cb129b5f0                     7               positive
# 4470  97febaedbacc8d1                    11               positive
# 4472  2f7947d9967020a                     7               positive
# 4478  dc6d0d70a403e86                     8               positive
# 4493  858f4eacd1eef8e                    15               positive
# 4502  0754a9b6e55f338                     8               positive
# 4510  dbca19777e00c8a                    17               positive
# 4515  5c493f44b830ac3                     9               positive
# 4522  b25cc4ab4e70656                     4               positive
# 4524  e2205d15250a321                    17               positive
# 4528  6345053242dd4e8                    10               positive
# 4535  0502def18bdfe50                    12               positive
# 4541  07d39d64321e119                     9               positive
# 4546  ad599a6a1be4a36                     6               positive
# 4553  b431031c1db777b                    10               positive
# 4568  a01d479ed587706                    16               positive
# 4582  9d61fbb8d21b7eb                     7               positive
# 4594  b987d39e9ba817c                    18               positive
# 4599  74064fb650b57e7                    15               positive
# 4603  50c45c8d5f44e36                    12               positive
# 4605  0ead797997157de                    19               positive
# 4617  c5390833efa492d                    11               positive
# 4624  ada8425f217719e                    11               positive
# 4646  b388e20effbbf0b                    18               positive
# 4647  50924779ff50bb4                    19               positive
# 4653  6c66b6140d1e19a                     5               positive
# 4654  819854a9a5235fd                    14               positive
# 4656  787a2cd349455f4                    15               positive
# 4680  5ae49b7c4583a5f                     9               positive
# 4685  058f1fad0e6cf32                    12               positive
# 4696  75fda5b7adddcd8                    17               positive
# 4701  a2fec63edc89499                    10               positive
# 4706  65a4e53487d2564                    14               positive
# 4716  4da3ec893e1b628                     8               positive
# 4719  bb97a558fd97930                    12               positive
# 4720  35c9659c7a3be84                    11               positive
# 4721  41b921b4927de68                    12               positive
# 4744  1b735fca0859932                     1               positive
# 4758  c961ddfcdb8486c                    11               positive
# 4769  a8fdfcf1ee5ed62                    17               positive
# 4777  17319c86ff7db04                    18               positive
# 4783  492a6d84003b7fb                     7               positive
# 4784  580e5aa69c657e1                     7               positive
# 4792  9c39067a4ff440c                    15               positive
# 4854  933175fe0838806                    19               positive
# 4857  4394012a24db034                     8               positive
# 4863  1e29f841c72888e                    18               positive
# 4896  2492e2202f672fa                    16               positive
# 4897  30bfb33927acb18                    18               positive
# 4899  680d440c979e1f1                    18               positive
# 4901  88547fa3b9fafa6                    10               positive
# 4905  654f3e5f971cb9c                    13               positive
# 4924  e1ed5e1095ae65d                     7               positive
# 4946  41e511d6bf74aeb                    19               positive
# 4955  1dfbda7740aabe5                    14               positive
# 4957  30cb1119e01ee90                    11               positive
# 4964  a7bc77ac8caf300                    16               positive
# 4969  d3b467ef1fa5dd3                    13               positive
# 4974  d5e8c0aacb2ec96                    10               positive
# 4978  61dd2fab8e61a9e                    12               positive
# 4980  dd49ffef95a1fa5                     8               positive
# 4989  749d93ed66938fb                    18               positive
# 4999  da28d7fbf4bfef5                     5               positive
# 5000  acb3ff67403ec5f                    19               positive
# 5002  2136a024e2b5c9c                    12               positive
# 5004  e5aa8b867b628f4                    15               positive
# 5009  d0d7a0ee8d7e277                    15               positive
# 5016  c3c08e6b5fb20d7                    12               positive
# 5017  c68a37fa5820769                    18               positive
# 5022  b957a7b9fb95ef2                    13               positive
# 5023  8fd2c84df1bc2d4                    19               positive
# 5038  4b4f708e7ef0661                    12               positive
# 5044  0562780ddd02d02                     8               positive
# 5048  3918421c87c971e                    19               positive
# 5051  6a39a4901fd86c7                     5               positive
# 5055  aa4b8e58e522f0c                    19               positive
# 5058  43c2d654b905768                    12               positive
# 5060  4df295cc378435e                    15               positive
# 5069  7593ce525a6ca3c                    19               positive
# 5070  55da004bceb92ba                    18               positive
# 5071  07b49072f096ad7                    16               positive
# 5075  c0ebdd499028cc5                    10               positive
# 5076  69a46fb58ba1651                    17               positive
# 5077  d7df6d36f04895d                     5               positive
# 5078  101888b2a456c3c                    16               positive
# 5080  e7c5930d5ac5e84                    13               positive
# 5086  289366adc2ef3c7                     3               positive
# 5088  3445d0cf18dce7c                     6               positive
# 5090  1d1bba559444833                    18               positive
# 5092  1005f643815219f                    14               positive
# 5094  1932db8070b16e8                     6               positive
# 5095  36a2e7d1c6adb21                     9               positive
# 5101  7c0d7dc60a784dd                     4               positive
# 5102  23b82b083ab5043                     5               positive
# 5103  e4ce29cb0cf3cd2                     7               positive
# 5111  6efc63ca6d085c1                    14               positive
# 5115  1a51e30b49fe00c                    15               positive
# 5116  788c74d28600e6f                    19               positive
# 5117  3616450ff040649                    11               positive
# 5118  cafb672ac239cb4                     6               positive
# 5125  9e59cc3a2006cf0                     4               positive
# 5126  10495255e7b858c                    14               positive
# 5129  cef516d5844dc30                    15               positive
# 5132  0f8e1451d83332a                    10               positive
# 5134  07bd63d315e90e6                     6               positive
# 5138  843caa5d5ed9483                    11               positive
# 5142  71a352a79e9da73                     9               positive
# 5145  eedfe6a670c46cc                     8               positive
# 5146  92e0bfef94cfaba                    18               positive
# 5147  9fda18a2ecfa3a1                     4               positive
# 5151  5d8ad9fe8d82875                    10               positive
# 5154  68efa08e466dcf3                    18               positive
# 5156  cd90359733fc0c8                    11               positive
# 5161  8e0f05695e89b36                    19               positive
# 5165  88baf02b9f4c1b3                    14               positive
# 5166  51757767ea58753                     9               positive
# 5169  e4170692991ff53                     1               positive
# 5171  15f441a05ed428a                    16               positive
# 5177  ea3964af1e60043                    13               positive
# 5178  49b3e2f0e685e26                    19               positive
# 5179  0c67073cbe6e84c                    15               positive
# 5180  a92497786608730                     8               positive
# 5183  1df576ec017f9aa                     9               positive
# 5184  d775dad6db39e63                    16               positive
# 5185  eccb14d81c14548                    18               positive
# 5188  8889316fc392c96                     4               positive
# 5190  b49fb6a98832e7c                    14               positive
# 5194  2193bf8cfe6a889                    14               positive
# 5196  d584d2cf7d09e1e                    11               positive
# 5199  2a063f32d190ed7                    11               positive
# 5201  ed91fbfaeb762fb                    19               positive
# 5204  feed83fdc172b83                    13               positive
# 5205  a12d416ab6b668b                     5               positive
# 5207  258ed11c4f04af3                    14               positive
# 5208  5b7a01982d8f246                    18               positive
# 5210  07484308b83fba7                    15               positive
# 5211  640111c4d830c1d                    19               positive
# 5216  a7cb2ff3d02069e                    11               positive
# 5223  6c66c5e197e6b13                     6               positive
# 5225  94945bb41918d5a                    17               positive
# 5226  482a960eb07d3cd                    16               positive
# 5228  9553886457728b3                    10               positive
# 5230  8f5ce45d3cb9a97                    13               positive
# 5237  7971384a8662be3                    11               positive
# 5247  6d83e6ce3f3bad3                     3               positive
# 5248  67aae6f51a8da48                    17               positive
# 5250  59c5e1c27d6f690                    19               positive
# 5252  561fd94e9feef0b                    19               positive
# 5256  f39a9ffe1147112                    11               positive
# 5258  da66f5159bd2209                    19               positive
# 5259  0f4555b42f5af21                    10               positive
# 5260  6e02b81c19b53f4                    19               positive
# 5263  a44fdb4d153ce4a                     9               positive
# 5264  11d1095e66240ca                     6               positive
# 5268  f5b08d9df162d9e                     7               positive
# 5269  bf7303310dd1e13                     4               positive
# 5270  20652ee463f3273                    13               positive
# 5271  ef75bb6d9539316                    11               positive
# 5274  d03f183171af496                     4               positive
# 5276  4a8d7594189b182                     9               positive
# 5277  64c83348e124c02                     5               positive
# 5282  f146b137238f294                     5               positive
# 5286  bfb247c5520313f                    17               positive
# 5289  05c257c013dfeeb                    15               positive
# 5290  f40d7b437db35a4                    10               positive
# 5292  bba9b8d8a76216d                    17               positive
# 5295  577c0741af38042                     7               positive
# 5298  30cba6755335f02                    13               positive
# 5301  e551dc478834539                     9               positive
# 5302  f0334ccdc07d4b8                     3               positive
# 5303  ca9f86ee13dccb0                     9               positive
# 5304  38399ee17c502be                     6               positive
# 5305  59463f1fe369943                     6               positive
# 5306  09fd1ea76a8cec3                     4               positive
# 5307  b1e79cf0b7d055c                    18               positive
# 5308  7344b0260dbb1bc                     9               positive
# 5309  198ca73d598db7d                    16               positive
# 5311  2291bf154268320                    10               positive
# 5312  be8b5cb24d6f7e8                     9               positive
# 5314  13201f25abc377e                     4               positive
# 5316  b444fb4114d2b89                    10               positive
# 5319  369b11f27e46843                     5               positive
# 5320  3e720af2a20ad39                    11               positive
# 5324  0b74a4586762422                    15               positive
# 5325  cba554bbdeb01e4                     5               positive
# 5328  73e57cd78b5e5a9                     9               positive
# 5329  c75670d37898838                    17               positive
# 5333  d318ce17a7bd3f2                    16               positive
# 5335  2a3cfbaae1e9225                     7               positive
# 5338  59ece6d81c0515d                     4               positive
# 5339  0d55207efba4fda                     9               positive
# 5341  1202e7779b0d403                    13               positive
# 5342  5be08627b17f44e                     4               positive
# 5345  ab55ddd24336faf                     4               positive
# 5346  54a15afdee88ace                    11               positive
# 5347  441e4642daf958a                     9               positive
# 5349  f4c16de5820fc48                     7               positive
# 5350  18820907286127b                     6               positive
# 5352  ce3bf73772b25b6                    17               positive
# 5353  00b95f98f09259c                     5               positive
# 5354  e9e0f6c33992143                    10               positive
# 5355  4767c5136031395                    16               positive
# 5356  d71cf32cf75c010                    15               positive
# 5357  ebcce7f0816ff4f                    15               positive
# 5358  c4e44daa2370b21                     9               positive
# 5361  a495fa132dba01f                    15               positive
# 5367  b8ab6ebdc192b8f                     4               positive
# 5369  99dfd79ed298c6f                    18               positive
# 5370  aa90a09b1cbd941                     5               positive
# 5371  2bc073d3ff6058b                     9               positive
# 5375  72a12cea73b65ba                    19               positive
# 5377  a9f59bea0b7560e                    19               positive
# 5381  60a21b736b51ff0                    15               positive
# 5383  04dd5f4355a3f95                    19               positive
# 5393  29cf377dc7852b1                     6               positive
# 5394  dfeaa763e8ca60f                     3               positive
# 5401  9bbf08d1b8fb567                    10               positive
# 5402  8d6ceb7c8b4ea03                    11               positive
# 5406  c54f648a790d680                    15               positive
# 5414  6fe9121f52e04ae                    15               positive
# 5415  45a4cdf4f566866                    15               positive
# 5416  dd3b7c940159225                     4               positive
# 5419  47f9253702d25bf                     8               positive
# 5421  0ce6c167922fb52                     5               positive
# 5423  dbf2abfc23f3682                    17               positive
# 5439  3c40daf80aa3dbc                    11               positive
# 5440  54000754a0d63d6                     8               positive
# 5441  ed174b49d031f08                     4               positive
# 5444  b8df595cf65e5a2                     3               positive
# 5446  529d1deb9926cfd                    16               positive
# 5447  b09e5b863e74272                    15               positive
# 5455  3eb67fd095c7fb7                    10               positive
# 5456  7d0cbc910f36bdc                    13               positive
# 5462  d0edeaaf2555ac7                    14               positive
# 5468  8363fef03374623                     8               positive
# 5475  d05bb29e0277d7f                    13               positive
# 5478  8fe5c56e3ac977f                     8               positive
# 5480  20858f287b5da5f                    15               positive
# 5481  6e34d33b9733d20                     8               positive
# 5484  4e442b4fa877c3d                    13               positive
# 5485  72eaf5878263562                    16               positive
# 5495  b18031aa347b761                     3               positive
# 5498  d3e0dc7a06642e2                    17               positive
# 5502  dbc17c7cdde6648                    11               positive
# 5507  661c633ef1b635c                     4               positive
# 5509  fb7aa00f96ba894                     6               positive
# 5512  c4be78e7b9a1dba                     8               positive
# 5515  7e557904bc9881c                     6               positive
# 5521  f1ca35dce417f23                    12               positive
# 5522  07271ae627f853b                     4               positive
# 5524  389cfa141364ea0                    19               positive
# 5525  9bd47fc9d8fdd3f                     6               positive
# 5526  daa4f00cce37716                    11               positive
# 5529  35752c0c2789bd5                     9               positive
# 5532  f4ed86707a062f8                     4               positive
# 5533  67c110fa326d263                    11               positive
# 5534  150a4ebea6b75fa                     9               positive
# 5535  9211d5d726905b8                    13               positive
# 5537  094ad06472341b2                    18               positive
# 5538  a9c4bed37b534d8                     6               positive
# 5540  8f13c97fd23790d                    14               positive
# 5541  d27b16d1c45e2c7                     7               positive
# 5548  92ba78ce08feaf3                    14               positive
# 5550  203165c67027dd0                    13               positive
# 5551  05f0703db4a9723                     9               positive
# 5553  3489f380de1efd5                    18               positive
# 5555  bfff4e45c7a36e4                     4               positive
# 5556  4cb75d783860673                     6               positive
# 5560  ac9c45119c17cba                     9               positive
# 5563  d2aee596b5def62                     4               positive
# 5564  32f55e529808065                    12               positive
# 5565  0123beb6c71cae3                    13               positive
# 5566  f1c30ed80e63858                    14               positive
# 5569  57e884b257fdd45                    13               positive
# 5570  83bb9a36af1b447                     4               positive
# 5573  8ce1bc24ac6064c                     7               positive
# 5575  3023990b6885c98                    13               positive
# 5576  5912fff9b14d0a6                     9               positive
# 5577  c1d7638302c3051                     6               positive
# 5579  48f4e7a52d6b377                     6               positive
# 5580  8e2c6cf24d881ab                    10               positive
# 5585  0eec03a4743c4dd                    18               positive
# 5587  14b8a03798b9115                     4               positive
# 5589  71f47e536afa016                    12               positive
# 5591  0dbce06c620b4c7                    12               positive
# 5594  c751894e1f27d55                     9               positive
# 5596  64ce79c5fba6ab6                    11               positive
# 5597  5b8cc5cbf00f378                    14               positive
# 5598  11b940d108ad511                     9               positive
# 5600  1eed30082150280                     9               positive
# 5606  308051f5cb31480                     8               positive
# 5608  c47d8a893cfdb37                     5               positive
# 5610  346cc9dfc845f3e                     9               positive
# 5611  3e457279a460059                    16               positive
# 5619  d85d594eca6cbb1                    11               positive
# 5624  3e6bb16797c6675                    16               positive
# 5626  42f299bee500ca4                     7               positive
# 5627  c6031317982129c                     8               positive
# 5629  8a5cb77d0df382a                    15               positive
# 5631  7caec1803eac8d0                    16               positive
# 5632  5c386388ba3c3f0                    16               positive
# 5633  9f8dfe2ae239238                     4               positive
# 5634  db77903261ab6d0                    15               positive
# 5639  ae66feb9e4dc3a0                     3               positive
# 5643  2697fdccbfeb7f7                    19               positive
#
#      patient_addmited_to_regular_ward_1_yes_0_no  \
# 67                                             f
# 284                                            t
# 513                                            f
# 568                                            f
# 676                                            f
# 884                                            t
# 1011                                           f
# 1108                                           f
# 1113                                           f
# 1129                                           f
# 1156                                           t
# 1162                                           f
# 1168                                           t
# 1193                                           f
# 1194                                           f
# 1196                                           f
# 1201                                           f
# 1205                                           t
# 1232                                           f
# 1268                                           f
# 1293                                           f
# 1309                                           f
# 1313                                           f
# 1324                                           f
# 1328                                           f
# 1339                                           f
# 1348                                           f
# 1369                                           f
# 1387                                           f
# 1393                                           f
# 1394                                           f
# 1400                                           f
# 1404                                           f
# 1416                                           f
# 1423                                           f
# 1428                                           f
# 1431                                           f
# 1432                                           f
# 1442                                           f
# 1451                                           f
# 1460                                           f
# 1461                                           f
# 1476                                           f
# 1479                                           f
# 1487                                           f
# 1489                                           f
# 1494                                           f
# 1516                                           f
# 1517                                           f
# 1530                                           t
# 1533                                           f
# 1536                                           f
# 1539                                           f
# 1548                                           f
# 1566                                           f
# 1574                                           f
# 1576                                           f
# 1577                                           t
# 1586                                           f
# 1615                                           f
# 1624                                           f
# 1628                                           f
# 1644                                           f
# 1647                                           f
# 1651                                           f
# 1680                                           f
# 1698                                           f
# 1701                                           f
# 1705                                           f
# 1713                                           f
# 1723                                           f
# 1726                                           f
# 1749                                           f
# 1750                                           f
# 1786                                           f
# 1792                                           f
# 1796                                           f
# 1801                                           f
# 1844                                           f
# 1849                                           f
# 1858                                           f
# 1879                                           f
# 1885                                           f
# 1886                                           f
# 1898                                           f
# 1905                                           f
# 1962                                           f
# 1966                                           f
# 1973                                           f
# 2034                                           f
# 2038                                           f
# 2055                                           f
# 2074                                           f
# 2114                                           f
# 2119                                           f
# 2140                                           f
# 2141                                           f
# 2161                                           f
# 2167                                           f
# 2205                                           f
# 2206                                           f
# 2215                                           f
# 2237                                           f
# 2241                                           f
# 2249                                           f
# 2251                                           f
# 2252                                           f
# 2262                                           f
# 2299                                           f
# 2326                                           f
# 2336                                           f
# 2381                                           f
# 2392                                           f
# 2423                                           f
# 2426                                           f
# 2442                                           f
# 2466                                           f
# 2477                                           f
# 2484                                           f
# 2487                                           f
# 2527                                           f
# 2565                                           f
# 2569                                           f
# 2600                                           f
# 2679                                           f
# 2683                                           f
# 2722                                           f
# 2758                                           f
# 2816                                           f
# 2828                                           f
# 2834                                           f
# 2844                                           f
# 2865                                           f
# 2934                                           f
# 2950                                           f
# 2951                                           f
# 2959                                           f
# 2986                                           f
# 2993                                           f
# 3016                                           f
# 3026                                           f
# 3057                                           t
# 3060                                           f
# 3085                                           t
# 3108                                           f
# 3160                                           f
# 3161                                           f
# 3167                                           f
# 3184                                           f
# 3193                                           f
# 3210                                           f
# 3214                                           f
# 3254                                           f
# 3261                                           f
# 3281                                           f
# 3283                                           f
# 3295                                           f
# 3302                                           f
# 3325                                           f
# 3379                                           f
# 3384                                           f
# 3393                                           f
# 3394                                           f
# 3412                                           f
# 3458                                           f
# 3459                                           f
# 3462                                           f
# 3465                                           f
# 3471                                           f
# ...
# 3491                               NaN
# 3514                               NaN
# 3515                               NaN
# 3527                               NaN
# 3531                               NaN
# 3548                               NaN
# 3569                               NaN
# 3571                               NaN
# 3583                               NaN
# 3588                               NaN
# 3589                               NaN
# 3625                               NaN
# 3627                               NaN
# 3640                               NaN
# 3665                               NaN
# 3667                               NaN
# 3694                               NaN
# 3701                               NaN
# 3779                               NaN
# 3781                               NaN
# 3789                               NaN
# 3793                               NaN
# 3809                               NaN
# 3818                               NaN
# 3822                               NaN
# 3823                               NaN
# 3831                               NaN
# 3845                               NaN
# 3855                               NaN
# 3866                               NaN
# 3877                               NaN
# 3879                               NaN
# 3881                               NaN
# 3885                               NaN
# 3890                               NaN
# 3901                               NaN
# 3955                               NaN
# 3957                               NaN
# 3958                               NaN
# 3960                               NaN
# 3972                               NaN
# 3974                               NaN
# 3987                               NaN
# 4006                               NaN
# 4008                               NaN
# 4009                               NaN
# 4020                               NaN
# 4046                               NaN
# 4058                               NaN
# 4087                               NaN
# 4090                               NaN
# 4097                               NaN
# 4104                               NaN
# 4118                               NaN
# 4120                               NaN
# 4126                               NaN
# 4130                               NaN
# 4138                               NaN
# 4153                               NaN
# 4156                               NaN
# 4161                               NaN
# 4162                               NaN
# 4182                               NaN
# 4188                               NaN
# 4198                               NaN
# 4203                               NaN
# 4209                               NaN
# 4215                               NaN
# 4235                               NaN
# 4250                               NaN
# 4262                               NaN
# 4277                               NaN
# 4284                               NaN
# 4289                               NaN
# 4333                               NaN
# 4346                               NaN
# 4360                               NaN
# 4361                               NaN
# 4397                               NaN
# 4425                               NaN
# 4429                               NaN
# 4452                               NaN
# 4453                               NaN
# 4459                               NaN
# 4460                               NaN
# 4470                               NaN
# 4472                               NaN
# 4478                               NaN
# 4493                               NaN
# 4502                               NaN
# 4510                               NaN
# 4515                               NaN
# 4522                               NaN
# 4524                               NaN
# 4528                               NaN
# 4535                          0.902048
# 4541                               NaN
# 4546                               NaN
# 4553                               NaN
# 4568                               NaN
# 4582                               NaN
# 4594                               NaN
# 4599                               NaN
# 4603                               NaN
# 4605                               NaN
# 4617                               NaN
# 4624                               NaN
# 4646                               NaN
# 4647                               NaN
# 4653                               NaN
# 4654                               NaN
# 4656                               NaN
# 4680                               NaN
# 4685                               NaN
# 4696                               NaN
# 4701                               NaN
# 4706                               NaN
# 4716                               NaN
# 4719                               NaN
# 4720                               NaN
# 4721                               NaN
# 4744                               NaN
# 4758                               NaN
# 4769                               NaN
# 4777                               NaN
# 4783                               NaN
# 4784                               NaN
# 4792                               NaN
# 4854                               NaN
# 4857                               NaN
# 4863                               NaN
# 4896                               NaN
# 4897                               NaN
# 4899                               NaN
# 4901                               NaN
# 4905                               NaN
# 4924                               NaN
# 4946                               NaN
# 4955                               NaN
# 4957                               NaN
# 4964                               NaN
# 4969                               NaN
# 4974                               NaN
# 4978                               NaN
# 4980                               NaN
# 4989                               NaN
# 4999                               NaN
# 5000                               NaN
# 5002                               NaN
# 5004                               NaN
# 5009                         -0.844956
# 5016                               NaN
# 5017                               NaN
# 5022                               NaN
# 5023                               NaN
# 5038                               NaN
# 5044                               NaN
# 5048                               NaN
# 5051                               NaN
# 5055                               NaN
# 5058                               NaN
# 5060                               NaN
# 5069                         -0.742191
# 5070                               NaN
# 5071                               NaN
# 5075                               NaN
# 5076                               NaN
# 5077                               NaN
# 5078                               NaN
# 5080                               NaN
# 5086                               NaN
# 5088                               NaN
# 5090                               NaN
# 5092                               NaN
# 5094                               NaN
# 5095                               NaN
# 5101                               NaN
# 5102                               NaN
# 5103                               NaN
# 5111                               NaN
# 5115                               NaN
# 5116                               NaN
# 5117                               NaN
# 5118                               NaN
# 5125                               NaN
# 5126                               NaN
# 5129                               NaN
# 5132                               NaN
# 5134                               NaN
# 5138                               NaN
# 5142                               NaN
# 5145                               NaN
# 5146                               NaN
# 5147                               NaN
# 5151                               NaN
# 5154                               NaN
# 5156                               NaN
# 5161                         -1.153251
# 5165                          0.490988
# 5166                               NaN
# 5169                               NaN
# 5171                               NaN
# 5177                               NaN
# 5178                               NaN
# 5179                               NaN
# 5180                               NaN
# 5183                               NaN
# 5184                               NaN
# 5185                               NaN
# 5188                               NaN
# 5190                               NaN
# 5194                               NaN
# 5196                          0.182693
# 5199                               NaN
# 5201                               NaN
# 5204                               NaN
# 5205                               NaN
# 5207                               NaN
# 5208                               NaN
# 5210                          1.621402
# 5211                               NaN
# 5216                               NaN
# 5223                               NaN
# 5225                               NaN
# 5226                          0.182693
# 5228                               NaN
# 5230                               NaN
# 5237                               NaN
# 5247                               NaN
# 5248                               NaN
# 5250                          0.079928
# 5252                               NaN
# 5256                               NaN
# 5258                               NaN
# 5259                               NaN
# 5260                               NaN
# 5263                               NaN
# 5264                               NaN
# 5268                               NaN
# 5269                               NaN
# 5270                               NaN
# 5271                               NaN
# 5274                               NaN
# 5276                               NaN
# 5277                               NaN
# 5282                               NaN
# 5286                               NaN
# 5289                               NaN
# 5290                               NaN
# 5292                               NaN
# 5295                               NaN
# 5298                               NaN
# 5301                               NaN
# 5302                               NaN
# 5303                               NaN
# 5304                               NaN
# 5305                               NaN
# 5306                               NaN
# 5307                               NaN
# 5308                               NaN
# 5309                               NaN
# 5311                               NaN
# 5312                               NaN
# 5314                               NaN
# 5316                               NaN
# 5319                               NaN
# 5320                               NaN
# 5324                               NaN
# 5325                               NaN
# 5328                               NaN
# 5329                          0.799283
# 5333                               NaN
# 5335                               NaN
# 5338                               NaN
# 5339                               NaN
# 5341                               NaN
# 5342                               NaN
# 5345                               NaN
# 5346                               NaN
# 5347                               NaN
# 5349                               NaN
# 5350                               NaN
# 5352                               NaN
# 5353                               NaN
# 5354                               NaN
# 5355                               NaN
# 5356                               NaN
# 5357                               NaN
# 5358                               NaN
# 5361                               NaN
# 5367                               NaN
# 5369                               NaN
# 5370                               NaN
# 5371                               NaN
# 5375                               NaN
# 5377                               NaN
# 5381                               NaN
# 5383                               NaN
# 5393                               NaN
# 5394                               NaN
# 5401                               NaN
# 5402                               NaN
# 5406                               NaN
# 5414                               NaN
# 5415                               NaN
# 5416                               NaN
# 5419                               NaN
# 5421                               NaN
# 5423                         -0.639426
# 5439                               NaN
# 5440                               NaN
# 5441                               NaN
# 5444                               NaN
# 5446                               NaN
# 5447                               NaN
# 5455                               NaN
# 5456                               NaN
# 5462                               NaN
# 5468                               NaN
# 5475                               NaN
# 5478                               NaN
# 5480                               NaN
# 5481                               NaN
# 5484                               NaN
# 5485                               NaN
# 5495                               NaN
# 5498                               NaN
# 5502                               NaN
# 5507                               NaN
# 5509                               NaN
# 5512                               NaN
# 5515                               NaN
# 5521                               NaN
# 5522                               NaN
# 5524                               NaN
# 5525                               NaN
# 5526                               NaN
# 5529                               NaN
# 5532                               NaN
# 5533                               NaN
# 5534                               NaN
# 5535                               NaN
# 5537                               NaN
# 5538                               NaN
# 5540                               NaN
# 5541                               NaN
# 5548                               NaN
# 5550                               NaN
# 5551                               NaN
# 5553                               NaN
# 5555                               NaN
# 5556                               NaN
# 5560                               NaN
# 5563                               NaN
# 5564                          0.902048
# 5565                               NaN
# 5566                          1.826932
# 5569                               NaN
# 5570                               NaN
# 5573                               NaN
# 5575                               NaN
# 5576                               NaN
# 5577                               NaN
# 5579                               NaN
# 5580                               NaN
# 5585                               NaN
# 5587                               NaN
# 5589                               NaN
# 5591                               NaN
# 5594                               NaN
# 5596                               NaN
# 5597                               NaN
# 5598                               NaN
# 5600                               NaN
# 5606                               NaN
# 5608                               NaN
# 5610                               NaN
# 5611                               NaN
# 5619                               NaN
# 5624                               NaN
# 5626                               NaN
# 5627                               NaN
# 5629                               NaN
# 5631                               NaN
# 5632                               NaN
# 5633                               NaN
# 5634                               NaN
# 5639                               NaN
# 5643                               NaN
#
# [558 rows x 111 columns]

# %%
df.columns

# %%
df_positive.dtypes
# Out:
# patient_id                                             object
# patient_age_quantile                                    int64
# sars_cov_2_exam_result                                 object
# patient_addmited_to_regular_ward_1_yes_0_no            object
# patient_addmited_to_semi_intensive_unit_1_yes_0_no     object
# patient_addmited_to_intensive_care_unit_1_yes_0_no     object
# hematocrit                                            float64
# hemoglobin                                            float64
# platelets                                             float64
# mean_platelet_volume                                  float64
# red_blood_cells                                       float64
# lymphocytes                                           float64
# mean_corpuscular_hemoglobin_concentration_mchc        float64
# leukocytes                                            float64
# basophils                                             float64
# mean_corpuscular_hemoglobin_mch                       float64
# eosinophils                                           float64
# mean_corpuscular_volume_mcv                           float64
# monocytes                                             float64
# red_blood_cell_distribution_width_rdw                 float64
# serum_glucose                                         float64
# respiratory_syncytial_virus                            object
# influenza_a                                            object
# influenza_b                                            object
# parainfluenza_1                                        object
# coronavirusnl63                                        object
# rhinovirus_enterovirus                                 object
# mycoplasma_pneumoniae                                 float64
# coronavirus_hku1                                       object
# parainfluenza_3                                        object
# chlamydophila_pneumoniae                               object
# adenovirus                                             object
# parainfluenza_4                                        object
# coronavirus229e                                        object
# coronavirusoc43                                        object
# inf_a_h1n1_2009                                        object
# bordetella_pertussis                                   object
# metapneumovirus                                        object
# parainfluenza_2                                        object
# neutrophils                                           float64
# urea                                                  float64
# proteina_c_reativa_mg_dl                              float64
# creatinine                                            float64
# potassium                                             float64
# sodium                                                float64
# influenza_b_rapid_test                                 object
# influenza_a_rapid_test                                 object
# alanine_transaminase                                  float64
# aspartate_transaminase                                float64
# gamma_glutamyltransferase                             float64
# total_bilirubin                                       float64
# direct_bilirubin                                      float64
# indirect_bilirubin                                    float64
# alkaline_phosphatase                                  float64
# ionized_calcium                                       float64
# strepto_a                                              object
# magnesium                                             float64
# pco2_venous_blood_gas_analysis                        float64
# hb_saturation_venous_blood_gas_analysis               float64
# base_excess_venous_blood_gas_analysis                 float64
# po2_venous_blood_gas_analysis                         float64
# fio2_venous_blood_gas_analysis                        float64
# total_co2_venous_blood_gas_analysis                   float64
# ph_venous_blood_gas_analysis                          float64
# hco3_venous_blood_gas_analysis                        float64
# rods                                                  float64
# segmented                                             float64
# promyelocytes                                         float64
# metamyelocytes                                        float64
# myelocytes                                            float64
# myeloblasts                                            object
# urine_esterase                                         object
# urine_aspect                                           object
# urine_ph                                               object
# urine_hemoglobin                                       object
# urine_bile_pigments                                    object
# urine_ketone_bodies                                    object
# urine_nitrite                                          object
# urine_density                                         float64
# urine_urobilinogen                                     object
# urine_protein                                          object
# urine_sugar                                           float64
# urine_leukocytes                                       object
# urine_crystals                                         object
# urine_red_blood_cells                                 float64
# urine_hyaline_cylinders                                object
# urine_granular_cylinders                               object
# urine_yeasts                                           object
# urine_color                                            object
# partial_thromboplastin_time_ptt                       float64
# relationship_patient_normal                           float64
# international_normalized_ratio_inr                    float64
# lactic_dehydrogenase                                  float64
# prothrombin_time_pt_activity                          float64
# vitamin_b12                                           float64
# creatine_phosphokinase_cpk                            float64
# ferritin                                              float64
# arterial_lactic_acid                                  float64
# lipase_dosage                                         float64
# d_dimer                                               float64
# albumin                                               float64
# hb_saturation_arterial_blood_gases                    float64
# pco2_arterial_blood_gas_analysis                      float64
# base_excess_arterial_blood_gas_analysis               float64
# ph_arterial_blood_gas_analysis                        float64
# total_co2_arterial_blood_gas_analysis                 float64
# hco3_arterial_blood_gas_analysis                      float64
# po2_arterial_blood_gas_analysis                       float64
# arteiral_fio2                                         float64
# phosphor                                              float64
# cto2_arterial_blood_gas_analysis                      float64
# dtype: object

# %%
df_positive.count()
# Out:
# patient_id                                            558
# patient_age_quantile                                  558
# sars_cov_2_exam_result                                558
# patient_addmited_to_regular_ward_1_yes_0_no           558
# patient_addmited_to_semi_intensive_unit_1_yes_0_no    558
# patient_addmited_to_intensive_care_unit_1_yes_0_no    558
# hematocrit                                             83
# hemoglobin                                             83
# platelets                                              83
# mean_platelet_volume                                   81
# red_blood_cells                                        83
# lymphocytes                                            83
# mean_corpuscular_hemoglobin_concentration_mchc         83
# leukocytes                                             83
# basophils                                              83
# mean_corpuscular_hemoglobin_mch                        83
# eosinophils                                            83
# mean_corpuscular_volume_mcv                            83
# monocytes                                              83
# red_blood_cell_distribution_width_rdw                  83
# serum_glucose                                          33
# respiratory_syncytial_virus                           112
# influenza_a                                           112
# influenza_b                                           112
# parainfluenza_1                                       112
# coronavirusnl63                                       112
# rhinovirus_enterovirus                                112
# mycoplasma_pneumoniae                                   0
# coronavirus_hku1                                      112
# parainfluenza_3                                       112
# chlamydophila_pneumoniae                              112
# adenovirus                                            112
# parainfluenza_4                                       112
# coronavirus229e                                       112
# coronavirusoc43                                       112
# inf_a_h1n1_2009                                       112
# bordetella_pertussis                                  112
# metapneumovirus                                       112
# parainfluenza_2                                       112
# neutrophils                                            75
# urea                                                   59
# proteina_c_reativa_mg_dl                               70
# creatinine                                             62
# potassium                                              58
# sodium                                                 58
# influenza_b_rapid_test                                 62
# influenza_a_rapid_test                                 62
# alanine_transaminase                                   40
# aspartate_transaminase                                 40
# gamma_glutamyltransferase                              30
# total_bilirubin                                        40
# direct_bilirubin                                       40
# indirect_bilirubin                                     40
# alkaline_phosphatase                                   29
# ionized_calcium                                         6
# strepto_a                                              14
# magnesium                                               5
# pco2_venous_blood_gas_analysis                         20
# hb_saturation_venous_blood_gas_analysis                20
# base_excess_venous_blood_gas_analysis                  20
# po2_venous_blood_gas_analysis                          20
# fio2_venous_blood_gas_analysis                          0
# total_co2_venous_blood_gas_analysis                    20
# ph_venous_blood_gas_analysis                           20
# hco3_venous_blood_gas_analysis                         20
# rods                                                    9
# segmented                                               9
# promyelocytes                                           9
# metamyelocytes                                          9
# myelocytes                                              9
# myeloblasts                                             9
# urine_esterase                                         11
# urine_aspect                                           12
# urine_ph                                               12
# urine_hemoglobin                                       12
# urine_bile_pigments                                    12
# urine_ketone_bodies                                     9
# urine_nitrite                                           0
# urine_density                                          12
# urine_urobilinogen                                     12
# urine_protein                                          10
# urine_sugar                                             0
# urine_leukocytes                                       12
# urine_crystals                                         12
# urine_red_blood_cells                                  12
# urine_hyaline_cylinders                                11
# urine_granular_cylinders                               12
# urine_yeasts                                           12
# urine_color                                            12
# partial_thromboplastin_time_ptt                         0
# relationship_patient_normal                            15
# international_normalized_ratio_inr                     23
# lactic_dehydrogenase                                   26
# prothrombin_time_pt_activity                            0
# vitamin_b12                                             0
# creatine_phosphokinase_cpk                             23
# ferritin                                                2
# arterial_lactic_acid                                   13
# lipase_dosage                                           3
# d_dimer                                                 0
# albumin                                                 0
# hb_saturation_arterial_blood_gases                     13
# pco2_arterial_blood_gas_analysis                       13
# base_excess_arterial_blood_gas_analysis                13
# ph_arterial_blood_gas_analysis                         13
# total_co2_arterial_blood_gas_analysis                  13
# hco3_arterial_blood_gas_analysis                       13
# po2_arterial_blood_gas_analysis                        13
# arteiral_fio2                                           9
# phosphor                                                1
# cto2_arterial_blood_gas_analysis                       13
# dtype: int64

# %%
df_positive.isnull().sum()

# %%
df_positive_selected_features = (df_positive[["patient_addmited_to_intensive_care_unit_1_yes_0_no",
                                              "patient_age_quantile",
                                              "hematocrit",
                                              "hemoglobin",
                                              "platelets",
                                              "mean_platelet_volume",
                                              "red_blood_cells",
                                              "lymphocytes",
                                              "basophils",
                                              "mean_corpuscular_hemoglobin_mch",
                                              "eosinophils",
                                              "mean_corpuscular_volume_mcv",
                                              "monocytes",
                                              "red_blood_cell_distribution_width_rdw",
#                                               "serum_glucose",
#                                               "coronavirus_hku1",
#                                               "influenza_a",
#                                               "influenza_b",
#                                               "parainfluenza_1",
#                                               "coronavirusnl63",
#                                               "coronavirusoc43",
#                                               "chlamydophila_pneumoniae",
#                                               "adenovirus","parainfluenza_4",
#                                               "coronavirusoc43"
                                             ]])

df_positive_selected_features_drop = df_positive_selected_features.dropna()
df_positive_selected_features_drop.count()
# Out:
# patient_addmited_to_intensive_care_unit_1_yes_0_no    81
# patient_age_quantile                                  81
# hematocrit                                            81
# hemoglobin                                            81
# platelets                                             81
# mean_platelet_volume                                  81
# red_blood_cells                                       81
# lymphocytes                                           81
# basophils                                             81
# mean_corpuscular_hemoglobin_mch                       81
# eosinophils                                           81
# mean_corpuscular_volume_mcv                           81
# monocytes                                             81
# red_blood_cell_distribution_width_rdw                 81
# dtype: int64

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
#selected_features = df[['names', 'of', 'selected', 'features', 'here']]
# X= df_positive.drop(["patient_addmited_to_intensive_care_unit_1_yes_0_no","sars_cov_2_exam_result","patient_id","patient_addmited_to_regular_ward_1_yes_0_no","patient_addmited_to_semi_intensive_unit_1_yes_0_no"], axis=1)
X=df_positive_selected_features_drop.drop("patient_addmited_to_intensive_care_unit_1_yes_0_no", axis =1)
# y= df[["koi_disposition"]].values.reshape(-1, 1)
# y= df_positive["patient_addmited_to_intensive_care_unit_1_yes_0_no"]
y= df_positive_selected_features_drop["patient_addmited_to_intensive_care_unit_1_yes_0_no"]


X.shape
# Out:
# (81, 13)

# %%
# X["influenza_b"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'influenza_b'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-114cb2532522> in <module>
# ----> 1 X["influenza_b"].value_counts()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'influenza_b'

# %%
y.value_counts()
# Out:
# f    73
# t     8
# Name: patient_addmited_to_intensive_care_unit_1_yes_0_no, dtype: int64

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
# from sklearn.compose import ColumnTransformer
# from sklearn.compose import make_column_transformer
# from sklearn.compose import make_column_selector

# ct = make_column_transformer(
# #     (StandardScaler(), make_column_selector(dtype_include=np.number)),
#     (OneHotEncoder(), make_column_selector(dtype_include=object))
# )
# ct.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-4aa83b1bab2a> in <module>
#       7     (OneHotEncoder(), make_column_selector(dtype_include=object))
#       8 )
# ----> 9 ct.fit_transform(X)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y)
#     527         self._validate_transformers()
#     528         self._validate_column_callables(X)
# --> 529         self._validate_remainder(X)
#     530
#     531         result = self._fit_transform(X, y, _fit_transform_one)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in _validate_remainder(self, X)
#     325         cols = []
#     326         for columns in self._columns:
# --> 327             cols.extend(_get_column_indices(X, columns))
#     328
#     329         remaining_idx = sorted(set(range(self._n_features)) - set(cols))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/__init__.py in _get_column_indices(X, key)
#     447                 col_idx = all_columns.get_loc(col)
#     448                 if not isinstance(col_idx, numbers.Integral):
# --> 449                     raise ValueError(f"Selected columns, {columns}, are not "
#     450                                      "unique in dataframe")
#     451                 column_indices.append(col_idx)
#
# ValueError: Selected columns, ['coronavirus_hku1', 'influenza_a', 'influenza_b', 'parainfluenza_1', 'coronavirusnl63', 'coronavirusoc43', 'chlamydophila_pneumoniae', 'adenovirus', 'parainfluenza_4', 'coronavirusoc43'], are not unique in dataframe

# %%
# X
# Out:
#       patient_age_quantile  hematocrit  hemoglobin  platelets  \
# 568                      2    0.991838    0.792188  -0.341548
# 884                     15   -0.495919   -0.398276  -0.718402
# 1108                    14   -0.312811   -0.648900  -0.027502
# 1162                    14   -0.518807   -0.272964  -0.215930
# 1494                     5   -0.015259   -0.147652  -1.007324
# 1624                    10    1.037616    1.481403  -1.823841
# 1966                    14    1.312279    1.606716  -1.685661
# 3057                    17    0.167850    0.165628  -1.007324
# 3779                    12    0.946061    0.980156  -0.605346
# 4120                     7    0.076295    0.290940  -0.655593
# 4459                    19   -0.106813   -0.272964  -0.894267
# 4510                    17    0.442512    0.290940  -1.258560
# 4524                    17    1.060504    0.980156  -0.856582
# 4535                    12    0.534067    0.416252  -0.944515
# 4646                    18    0.762952    0.541564  -1.748470
# 4769                    17    0.602732    0.917499  -1.183189
# 4777                    18   -0.930802   -1.150148   0.035307
# 4899                    18    1.609830    1.732028  -0.693278
# 4924                     7    0.694287    0.854844  -0.178244
# 4957                    11    1.564053    1.794683  -0.730964
# 4978                    12    0.762952    0.478908  -0.555098
# 4980                     8    0.076295    0.165628  -0.957076
# 5002                    12   -0.381476   -0.335620  -1.245998
# 5004                    15   -0.244145   -0.210308  -0.567660
# 5009                    15   -0.427254   -0.022340  -1.107818
# 5016                    12   -1.319907   -1.150148   0.273981
# 5017                    18   -0.358588   -0.147652   0.273981
# 5022                    13    1.174947    0.980156  -0.190806
# 5111                    14    0.923173    0.666876  -1.258560
# 5146                    18    0.968950    0.792188  -0.504851
# 5161                    19   -0.473031   -0.648900  -0.165682
# 5165                    14    0.740064    1.042812  -1.245998
# 5169                     1   -1.159688   -1.087492   0.512655
# 5196                    11   -0.450142    0.040316  -0.492289
# 5201                    19   -0.495919   -0.648900  -1.635414
# 5208                    18    1.358055    1.356092  -0.693278
# 5223                     6    1.129169    1.168124  -0.328986
# 5226                    16   -0.427254   -0.210308  -1.271122
# 5228                    10   -0.679027   -0.648900  -0.178244
# 5230                    13    0.923173    1.105468  -1.346492
# 5250                    19    0.556955    0.478908  -0.969638
# 5260                    19   -0.518807   -0.774212  -1.321369
# 5329                    17    0.968950    1.105468  -0.127997
# 5414                    15   -0.244145    0.102972  -1.170627
# 5423                    17   -0.358588   -0.460932  -0.153121
# 5524                    19   -0.793470   -0.774212  -0.316424
# 5540                    14   -0.312811    0.040316  -0.592784
# 5564                    12    1.152058    0.604220  -0.529975
# 5566                    14    1.106281    1.042812  -0.253615
# 5585                    18    1.197836    1.356092  -1.911774
#
#       mean_platelet_volume  red_blood_cells  lymphocytes  basophils  \
# 568               1.469188         1.653476    -0.048383   1.303529
# 884              -0.438097        -0.567950    -0.935404  -1.140144
# 1108             -0.101517        -0.656101    -0.099557  -0.529226
# 1162              0.459449        -0.515058    -0.457777  -0.223767
# 1494              0.908221        -0.550319     1.614780  -0.223767
# 1624              0.347255         1.142196     0.966573  -0.223767
# 1966              1.244801         1.547694     0.386598  -0.223767
# 3057              0.571643        -0.021409    -0.082499   0.081693
# 3779              0.908221         1.071674     0.906870   0.081693
# 4120              0.459449        -0.039039    -1.080398   0.081693
# 4459              0.796029        -0.338755    -0.346900   0.081693
# 4510              2.030154         0.401720    -0.449248  -0.529226
# 4524              0.459449         1.494802     0.164843   0.692611
# 4535             -0.325903         0.648545     0.369540  -0.223767
# 4646             -0.213711         0.278308     0.864224  -1.140144
# 4769             -0.101517         0.472242     0.062494  -0.834685
# 4777             -0.325903        -1.661031    -0.884230   1.303529
# 4899             -0.662483         1.600584    -1.071869   0.387152
# 4924             -0.662483         0.930631    -0.287196  -0.223767
# 4957              0.122869         1.459542    -1.054811  -0.223767
# 4978              0.122869         1.318499     0.574237   0.387152
# 4980             -0.325903         0.137265    -0.406603  -0.223767
# 5002             -0.774677        -0.303494     0.710702   0.387152
# 5004              0.683835        -0.444537     0.710702  -0.223767
# 5009             -0.550290        -0.250603     0.147785  -0.223767
# 5016             -0.325903        -1.308424    -1.268037   0.081693
# 5017              0.122869        -0.127191    -1.694489  -1.140144
# 5022             -0.438097         1.054043     1.162741   0.387152
# 5111              0.796029         0.454611    -0.014267  -1.140144
# 5146             -0.550290         1.089304     1.196857  -0.223767
# 5161              0.235063        -0.691362     0.053965   2.219906
# 5165              0.010677         0.860109    -1.012165  -1.140144
# 5169             -1.896609        -0.479797    -1.694489  -1.140144
# 5196             -0.774677        -0.409276    -1.378914  -0.529226
# 5201              0.683835        -0.973448     0.292779  -0.529226
# 5208             -0.213711         1.900301    -0.253080  -0.223767
# 5223             -1.223449         0.860109     1.128625   0.998070
# 5226             -0.325903        -0.374015    -0.031325  -0.223767
# 5228              0.796029        -0.127191     0.113669  -0.529226
# 5230              0.347255         1.159825    -0.005738   0.081693
# 5250              1.132609         0.119635    -0.756294  -0.529226
# 5260              0.683835        -0.567950    -0.287196  -0.529226
# 5329             -0.662483         0.930631    -0.039854   0.692611
# 5414              1.132609        -0.585580    -0.679533  -1.140144
# 5423              0.122869        -0.215342    -1.353327  -0.529226
# 5524              1.020415        -0.638471     0.582766  -0.529226
# 5540              0.571643        -0.338755     1.589193  -0.223767
# 5564              0.010677         0.930631    -0.679533   0.081693
# 5566             -0.438097         0.930631    -0.483364  -0.529226
# 5585              1.132609         0.384090     0.966573  -0.529226
#
#       mean_corpuscular_hemoglobin_mch  eosinophils  ...  coronavirus_hku1  \
# 568                         -1.442245    -0.498393  ...      not_detected
# 884                          0.334989    -0.666950  ...      not_detected
# 1108                         0.021361     0.175837  ...      not_detected
# 1162                         0.439533    -0.709090  ...      not_detected
# 1494                         0.753163     0.470813  ...      not_detected
# 1624                         0.387261    -0.835508  ...      not_detected
# 1966                        -0.083183    -0.751229  ...      not_detected
# 3057                         0.282719    -0.835508  ...      not_detected
# 3779                        -0.292269     1.060764  ...      not_detected
# 4120                         0.544077    -0.371974  ...      not_detected
# 4459                         0.125903    -0.835508  ...      not_detected
# 4510                        -0.292269    -0.456253  ...      not_detected
# 4524                        -0.919529    -0.751229  ...      not_detected
# 4535                        -0.501356    -0.709090  ...      not_detected
# 4646                         0.387261     0.007280  ...      not_detected
# 4769                         0.648619    -0.709090  ...      not_detected
# 4777                         1.275878     0.260116  ...      not_detected
# 4899                         0.021361    -0.582671  ...      not_detected
# 4924                        -0.239998    -0.751229  ...      not_detected
# 4957                         0.334989    -0.498393  ...      not_detected
# 4978                        -1.442245    -0.540532  ...      not_detected
# 4980                        -0.030911    -0.414114  ...      not_detected
# 5002                        -0.083183     0.175837  ...      not_detected
# 5004                         0.439533    -0.709090  ...      not_detected
# 5009                         0.387261    -0.287696  ...      not_detected
# 5016                         0.439533    -0.709090  ...      not_detected
# 5017                        -0.083183    -0.835508  ...      not_detected
# 5022                        -0.239998    -0.161278  ...      not_detected
# 5111                         0.282719    -0.835508  ...      not_detected
# 5146                        -0.605899    -0.709090  ...      not_detected
# 5161                         0.125903    -0.624811  ...      not_detected
# 5165                         0.178175    -0.835508  ...      not_detected
# 5169                        -1.128615    -0.835508  ...      not_detected
# 5196                         0.805435    -0.835508  ...      not_detected
# 5201                         0.700891    -0.709090  ...      not_detected
# 5208                        -0.971801    -0.835508  ...      not_detected
# 5223                         0.387261     0.007280  ...      not_detected
# 5226                         0.282719    -0.709090  ...      not_detected
# 5228                        -0.971801    -0.751229  ...      not_detected
# 5230                        -0.239998    -0.498393  ...      not_detected
# 5250                         0.596348    -0.835508  ...      not_detected
# 5260                        -0.396813    -0.751229  ...      not_detected
# 5329                         0.178175    -0.751229  ...      not_detected
# 5414                         1.328151    -0.835508  ...      not_detected
# 5423                        -0.449085    -0.666950  ...      not_detected
# 5524                        -0.239998    -0.835508  ...      not_detected
# 5540                         0.700891    -0.456253  ...      not_detected
# 5564                        -0.658171    -0.456253  ...      not_detected
# 5566                         0.073631    -0.793368  ...      not_detected
# 5585                         1.589509    -0.582671  ...      not_detected
#
#        influenza_a   influenza_b parainfluenza_1 coronavirusnl63  \
# 568   not_detected  not_detected    not_detected    not_detected
# 884   not_detected  not_detected    not_detected    not_detected
# 1108  not_detected  not_detected    not_detected    not_detected
# 1162  not_detected  not_detected    not_detected    not_detected
# 1494  not_detected  not_detected    not_detected    not_detected
# 1624  not_detected  not_detected    not_detected    not_detected
# 1966  not_detected  not_detected    not_detected    not_detected
# 3057  not_detected  not_detected    not_detected    not_detected
# 3779  not_detected  not_detected    not_detected    not_detected
# 4120  not_detected  not_detected    not_detected    not_detected
# 4459  not_detected  not_detected    not_detected    not_detected
# 4510  not_detected  not_detected    not_detected    not_detected
# 4524  not_detected  not_detected    not_detected    not_detected
# 4535  not_detected  not_detected    not_detected    not_detected
# 4646  not_detected  not_detected    not_detected    not_detected
# 4769  not_detected  not_detected    not_detected    not_detected
# 4777  not_detected  not_detected    not_detected    not_detected
# 4899  not_detected  not_detected    not_detected    not_detected
# 4924  not_detected  not_detected    not_detected    not_detected
# 4957  not_detected  not_detected    not_detected    not_detected
# 4978  not_detected  not_detected    not_detected    not_detected
# 4980  not_detected  not_detected    not_detected    not_detected
# 5002  not_detected  not_detected    not_detected    not_detected
# 5004  not_detected  not_detected    not_detected    not_detected
# 5009  not_detected  not_detected    not_detected    not_detected
# 5016  not_detected  not_detected    not_detected    not_detected
# 5017  not_detected  not_detected    not_detected    not_detected
# 5022  not_detected  not_detected    not_detected    not_detected
# 5111  not_detected  not_detected    not_detected    not_detected
# 5146  not_detected  not_detected    not_detected    not_detected
# 5161  not_detected  not_detected    not_detected    not_detected
# 5165  not_detected  not_detected    not_detected    not_detected
# 5169  not_detected      detected    not_detected        detected
# 5196  not_detected  not_detected    not_detected    not_detected
# 5201  not_detected  not_detected    not_detected    not_detected
# 5208  not_detected  not_detected    not_detected    not_detected
# 5223  not_detected  not_detected    not_detected    not_detected
# 5226  not_detected  not_detected    not_detected    not_detected
# 5228  not_detected  not_detected    not_detected    not_detected
# 5230  not_detected  not_detected    not_detected    not_detected
# 5250  not_detected  not_detected    not_detected    not_detected
# 5260  not_detected  not_detected    not_detected    not_detected
# 5329  not_detected  not_detected    not_detected    not_detected
# 5414  not_detected  not_detected    not_detected    not_detected
# 5423  not_detected  not_detected    not_detected    not_detected
# 5524  not_detected  not_detected    not_detected    not_detected
# 5540  not_detected  not_detected    not_detected    not_detected
# 5564  not_detected  not_detected    not_detected    not_detected
# 5566  not_detected  not_detected    not_detected    not_detected
# 5585  not_detected  not_detected    not_detected    not_detected
#
#      coronavirusoc43 chlamydophila_pneumoniae    adenovirus parainfluenza_4  \
# 568     not_detected             not_detected  not_detected    not_detected
# 884     not_detected             not_detected  not_detected    not_detected
# 1108    not_detected             not_detected  not_detected    not_detected
# 1162    not_detected             not_detected  not_detected    not_detected
# 1494    not_detected             not_detected  not_detected    not_detected
# 1624    not_detected             not_detected  not_detected    not_detected
# 1966    not_detected             not_detected  not_detected    not_detected
# 3057    not_detected             not_detected  not_detected    not_detected
# 3779    not_detected             not_detected  not_detected    not_detected
# 4120    not_detected             not_detected  not_detected    not_detected
# 4459    not_detected             not_detected  not_detected    not_detected
# 4510    not_detected             not_detected  not_detected    not_detected
# 4524    not_detected             not_detected  not_detected    not_detected
# 4535    not_detected             not_detected  not_detected    not_detected
# 4646    not_detected             not_detected  not_detected    not_detected
# 4769    not_detected             not_detected  not_detected    not_detected
# 4777    not_detected             not_detected  not_detected    not_detected
# 4899    not_detected             not_detected  not_detected    not_detected
# 4924    not_detected             not_detected  not_detected    not_detected
# 4957    not_detected             not_detected  not_detected    not_detected
# 4978    not_detected             not_detected  not_detected    not_detected
# 4980    not_detected             not_detected  not_detected    not_detected
# 5002    not_detected             not_detected  not_detected    not_detected
# 5004    not_detected             not_detected  not_detected    not_detected
# 5009    not_detected             not_detected  not_detected    not_detected
# 5016    not_detected             not_detected  not_detected    not_detected
# 5017    not_detected             not_detected  not_detected    not_detected
# 5022    not_detected             not_detected  not_detected    not_detected
# 5111    not_detected             not_detected  not_detected    not_detected
# 5146    not_detected             not_detected  not_detected    not_detected
# 5161    not_detected             not_detected  not_detected    not_detected
# 5165    not_detected             not_detected  not_detected    not_detected
# 5169    not_detected             not_detected  not_detected    not_detected
# 5196    not_detected             not_detected  not_detected    not_detected
# 5201    not_detected             not_detected  not_detected    not_detected
# 5208    not_detected             not_detected  not_detected    not_detected
# 5223    not_detected             not_detected  not_detected    not_detected
# 5226    not_detected             not_detected  not_detected    not_detected
# 5228    not_detected             not_detected  not_detected    not_detected
# 5230    not_detected             not_detected  not_detected    not_detected
# 5250    not_detected             not_detected  not_detected    not_detected
# 5260    not_detected             not_detected  not_detected    not_detected
# 5329    not_detected             not_detected  not_detected    not_detected
# 5414    not_detected             not_detected  not_detected    not_detected
# 5423    not_detected             not_detected  not_detected    not_detected
# 5524    not_detected             not_detected  not_detected    not_detected
# 5540    not_detected             not_detected  not_detected    not_detected
# 5564    not_detected             not_detected  not_detected    not_detected
# 5566    not_detected             not_detected  not_detected    not_detected
# 5585    not_detected             not_detected  not_detected    not_detected
#
#      coronavirusoc43
# 568     not_detected
# 884     not_detected
# 1108    not_detected
# 1162    not_detected
# 1494    not_detected
# 1624    not_detected
# 1966    not_detected
# 3057    not_detected
# 3779    not_detected
# 4120    not_detected
# 4459    not_detected
# 4510    not_detected
# 4524    not_detected
# 4535    not_detected
# 4646    not_detected
# 4769    not_detected
# 4777    not_detected
# 4899    not_detected
# 4924    not_detected
# 4957    not_detected
# 4978    not_detected
# 4980    not_detected
# 5002    not_detected
# 5004    not_detected
# 5009    not_detected
# 5016    not_detected
# 5017    not_detected
# 5022    not_detected
# 5111    not_detected
# 5146    not_detected
# 5161    not_detected
# 5165    not_detected
# 5169    not_detected
# 5196    not_detected
# 5201    not_detected
# 5208    not_detected
# 5223    not_detected
# 5226    not_detected
# 5228    not_detected
# 5230    not_detected
# 5250    not_detected
# 5260    not_detected
# 5329    not_detected
# 5414    not_detected
# 5423    not_detected
# 5524    not_detected
# 5540    not_detected
# 5564    not_detected
# 5566    not_detected
# 5585    not_detected
#
# [50 rows x 23 columns]

# %% [markdown]
# # Create a Train Test Split

# %%
from sklearn.model_selection import train_test_split

X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.head()
# Out:
#       patient_age_quantile  hematocrit  hemoglobin  platelets  \
# 5230                    13    0.923173    1.105468  -1.346492
# 1494                     5   -0.015259   -0.147652  -1.007324
# 5038                    12    1.655607    1.919995  -0.592784
# 4897                    18    0.396736    0.666876  -0.366671
# 5226                    16   -0.427254   -0.210308  -1.271122
#
#       mean_platelet_volume  red_blood_cells  lymphocytes  basophils  \
# 5230              0.347255         1.159825    -0.005738   0.081693
# 1494              0.908221        -0.550319     1.614780  -0.223767
# 5038              0.235063         2.182386     0.761876   0.387152
# 4897             -0.550290         0.207786    -0.781881   1.608988
# 5226             -0.325903        -0.374015    -0.031325  -0.223767
#
#       mean_corpuscular_hemoglobin_mch  eosinophils  \
# 5230                        -0.239998    -0.498393
# 1494                         0.753163     0.470813
# 5038                        -0.553627    -0.498393
# 4897                         0.753163    -0.709090
# 5226                         0.282719    -0.709090
#
#       mean_corpuscular_volume_mcv  monocytes  \
# 5230                    -0.675050   0.252494
# 1494                     1.147641   0.725232
# 5038                    -1.215847   0.698968
# 4897                     0.246311   0.961600
# 5226                    -0.074163   0.357547
#
#       red_blood_cell_distribution_width_rdw
# 5230                               0.524862
# 1494                               0.613318
# 5038                              -1.332725
# 4897                               0.524862
# 5226                              -0.978899

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# # Scale your data
# from sklearn.preprocessing import MinMaxScaler
# X_minmax = MinMaxScaler().fit(X_train)
# #y_minmax = MinMaxScaler().fit(y_train)

# X_train_minmax = X_minmax.transform(X_train)
# X_test_minmax = X_minmax.transform(X_test)
# #y_train_minmax = y_minmax.transform(y_train)
# #y_test_minmax = y_minmax.transform(y_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# # Create a random forest classifier
# rf = RandomForestClassifier(n_estimators=2000)
# rf = rf.fit(X_train, y_train)
# acc = rf.score(X_test, y_test)
# print(f"Training Data Score: {rf.score(X_train, y_train)}")
# print(f"Testing Data Score: {rf.score(X_test, y_test)}")

# %%
y_test.value_counts()
# Out:
# f    18
# t     3
# Name: patient_addmited_to_intensive_care_unit_1_yes_0_no, dtype: int64

# %%
y_train.value_counts()
# Out:
# f    55
# t     5
# Name: patient_addmited_to_intensive_care_unit_1_yes_0_no, dtype: int64

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
feature_importance= pd.DataFrame({
    "feature": X.columns.to_list(),
    "importance": rf.feature_importances_
    
})
feature_importance
# Out:
#                                   feature  importance
# 0                    patient_age_quantile    0.045083
# 1                              hematocrit    0.070726
# 2                              hemoglobin    0.058485
# 3                               platelets    0.095124
# 4                    mean_platelet_volume    0.097763
# 5                         red_blood_cells    0.068738
# 6                             lymphocytes    0.165500
# 7                               basophils    0.071427
# 8         mean_corpuscular_hemoglobin_mch    0.071652
# 9                             eosinophils    0.042590
# 10            mean_corpuscular_volume_mcv    0.088196
# 11                              monocytes    0.044737
# 12  red_blood_cell_distribution_width_rdw    0.079980

# %% [markdown]
# # SGD(Stochastic Gradient Decent) Classifier
# from sklearn.linear_model import SGDClassifier
# sgd = SGDClassifier(random_state=42)
# sgd.fit(X_train,y_train)
# acc = sgd.score(X_test, y_test)
# print(f"Training Data Score: {sgd.score(X_train, y_train)}")
# print(f"Testing Data Score: {sgd.score(X_test, y_test)}")

# %%
sgd.get_params()
# Out:
# {'alpha': 0.0001,
#  'average': False,
#  'class_weight': None,
#  'early_stopping': False,
#  'epsilon': 0.1,
#  'eta0': 0.0,
#  'fit_intercept': True,
#  'l1_ratio': 0.15,
#  'learning_rate': 'optimal',
#  'loss': 'hinge',
#  'max_iter': 1000,
#  'n_iter_no_change': 5,
#  'n_jobs': None,
#  'penalty': 'l2',
#  'power_t': 0.5,
#  'random_state': 42,
#  'shuffle': True,
#  'tol': 0.001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# # Naive Bayes
# from sklearn.naive_bayes import GaussianNB
# gnb = GaussianNB()
# gnb.fit(X_train, y_train)
# print(f"Training Data Score: {gnb.score(X_train, y_train)}")
# print(f"Testing Data Score: {gnb.score(X_test, y_test)}")

# %%
gnb.get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %% [markdown]
# ## Random Forest Tuning

# %%
## Random Forest Tuning
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV

param_grid = {
    'bootstrap': [True],
    'max_depth': [10,20,30],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
# grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
#                           cv = 3, n_jobs = -1, verbose = 2)
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                             n_jobs = -1, verbose = 2)

# %%
# Train the model with GridSearch
grid_search.fit(X_train, y_train)
grid_search.best_params_
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:   57.3s
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 1080 out of 1080 | elapsed:  1.7min finished
# {'bootstrap': True,
#  'max_depth': 10,
#  'max_features': 2,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8,
#  'n_estimators': 100}

# %%
best_grid = grid_search.best_estimator_
# print(f"Training Data Score: {best_grid.score(X_train_minmax, y_train)}")
# print(f"Testing Data Score: {best_grid.score(X_test_minmax, y_test)}")

# %%
best_model_rf= best_grid.fit(X_train,y_train)
print(f"Training Data Score: {best_model_rf.score(X_train, y_train)}")
print(f"Testing Data Score: {best_model_rf.score(X_test, y_test)}")
# print(f"Training Data Score: {best_grid.score(X_train_minmax, y_train)}")
# print(f"Testing Data Score: {best_grid.score(X_test_minmax, y_test)}")
# Out:
# Training Data Score: 0.9166666666666666
# Testing Data Score: 0.8571428571428571

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)

# %% [markdown]
# ## Naive Bayes Tuning

# %%
#Naive Baye Hyperparamter tuning
# Create the GridSearchCV model

param_grid = {
    'var_smoothing': [1e-10,5e-10,1e-9,5e-9,1e-8]

}
# Create a based model
gnb = GaussianNB()
# Instantiate the grid search model
# grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
#                           cv = 3, n_jobs = -1, verbose = 2)
grid_search_gnb = GridSearchCV(estimator = gnb, param_grid = param_grid, 
                             n_jobs = -1, verbose = 2)

# %%
# Train the model with GridSearch
grid_search_gnb.fit(X_train_minmax, y_train)
grid_search_gnb.best_params_

# %%
best_grid_gnb = grid_search_gnb.best_estimator_

# %%
best_model_gnb= best_grid_gnb.fit(X_train_minmax,y_train)
print(f"Training Data Score: {best_model_gnb.score(X_train_minmax, y_train)}")
print(f"Testing Data Score: {best_model_gnb.score(X_test_minmax, y_test)}")
# print(f"Training Data Score: {best_grid.score(X_train_minmax, y_train)}")
# print(f"Testing Data Score: {best_grid.score(X_test_minmax, y_test)}")

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'best_model_rf.sav'
joblib.dump(best_model_rf, filename)
filename1 = 'best_model_gnb.sav'
joblib.dump(best_model_gnb, filename1)
